# %% [markdown]
# #LOCAL TERMINAL RUN

# %%
# !pip install google-adk
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    os.environ["GOOGLE_GENAI_USE_VERTEXAI"] = "FALSE"
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}")
# Out:
# Requirement already satisfied: google-adk in c:\users\amana\anaconda3\lib\site-packages (1.18.0)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (6.0.2)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (4.11.0)
# Requirement already satisfied: authlib<2.0.0,>=1.5.1 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (1.6.5)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (8.1.8)
# Requirement already satisfied: fastapi<1.119.0,>=0.115.0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (0.121.1)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (2.187.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.125.0 in c:\users\amana\anaconda3\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.126.1)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-discoveryengine<0.14.0,>=0.13.12 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (0.13.12)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (2.25.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (3.59.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-storage<4.0.0,>=3.0.0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (3.5.0)
# Requirement already satisfied: google-genai<2.0.0,>=1.45.0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (1.49.0)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (0.21)
# Requirement already satisfied: mcp<2.0.0,>=1.8.0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (1.21.0)
# Requirement already satisfied: opentelemetry-api<=1.37.0,>=1.37.0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (1.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.36.0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp<2.0.0,>=1.9.0a0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-sdk<=1.37.0,>=1.37.0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (1.37.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (2.12.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in c:\users\amana\appdata\roaming\python\python313\site-packages (from google-adk) (2.9.0.post0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (1.1.0)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (2.32.5)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (1.17.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (2.0.39)
# Requirement already satisfied: starlette<1.0.0,>=0.46.2 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (0.49.3)
# Requirement already satisfied: tenacity<10.0.0,>=9.0.0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (9.0.0)
# Requirement already satisfied: typing-extensions<5,>=4.5 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (4.15.0)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (0.38.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in c:\users\amana\anaconda3\lib\site-packages (from google-adk) (15.0.1)
# Requirement already satisfied: idna>=2.8 in c:\users\amana\anaconda3\lib\site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\amana\anaconda3\lib\site-packages (from anyio<5.0.0,>=4.9.0->google-adk) (1.3.0)
# Requirement already satisfied: cryptography in c:\users\amana\anaconda3\lib\site-packages (from authlib<2.0.0,>=1.5.1->google-adk) (44.0.1)
# Requirement already satisfied: colorama in c:\users\amana\appdata\roaming\python\python313\site-packages (from click<9.0.0,>=8.1.8->google-adk) (0.4.6)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\amana\anaconda3\lib\site-packages (from fastapi<1.119.0,>=0.115.0->google-adk) (0.0.3)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in c:\users\amana\anaconda3\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.31.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in c:\users\amana\anaconda3\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.43.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in c:\users\amana\anaconda3\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.2.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in c:\users\amana\anaconda3\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in c:\users\amana\anaconda3\lib\site-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.2.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in c:\users\amana\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.72.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in c:\users\amana\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (6.33.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in c:\users\amana\anaconda3\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client<3.0.0,>=2.157.0->google-adk) (1.26.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\amana\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\amana\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\amana\anaconda3\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.9.1)
# Requirement already satisfied: packaging>=14.3 in c:\users\amana\appdata\roaming\python\python313\site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (25.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in c:\users\amana\anaconda3\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.38.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in c:\users\amana\anaconda3\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.15.0)
# Requirement already satisfied: shapely<3.0.0 in c:\users\amana\anaconda3\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.1.2)
# Requirement already satisfied: docstring_parser<1 in c:\users\amana\anaconda3\lib\site-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.17.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in c:\users\amana\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.76.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in c:\users\amana\anaconda3\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.76.0)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in c:\users\amana\anaconda3\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.0.0)
# Requirement already satisfied: google-cloud-trace<2 in c:\users\amana\anaconda3\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.17.0)
# Requirement already satisfied: google-cloud-logging<4 in c:\users\amana\anaconda3\lib\site-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.12.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.1 in c:\users\amana\anaconda3\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.0.0 in c:\users\amana\anaconda3\lib\site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.7.2)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in c:\users\amana\anaconda3\lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.7.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in c:\users\amana\anaconda3\lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.4.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in c:\users\amana\anaconda3\lib\site-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.14.3)
# Requirement already satisfied: sqlparse>=0.4.4 in c:\users\amana\anaconda3\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.5.3)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in c:\users\amana\anaconda3\lib\site-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.15.4)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in c:\users\amana\anaconda3\lib\site-packages (from google-cloud-storage<4.0.0,>=3.0.0->google-adk) (1.7.1)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\amana\anaconda3\lib\site-packages (from google-genai<2.0.0,>=1.45.0->google-adk) (0.28.1)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in c:\users\amana\anaconda3\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (3.2.0)
# Requirement already satisfied: certifi in c:\users\amana\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\amana\anaconda3\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\amana\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (0.16.0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\amana\anaconda3\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\amana\anaconda3\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (4.23.0)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\amana\anaconda3\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (2.6.1)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\amana\anaconda3\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.8.0->google-adk) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\amana\anaconda3\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.0.20)
# Requirement already satisfied: pywin32>=310 in c:\users\amana\appdata\roaming\python\python313\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\amana\anaconda3\lib\site-packages (from mcp<2.0.0,>=1.8.0->google-adk) (3.0.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\amana\anaconda3\lib\site-packages (from opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\amana\anaconda3\lib\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (3.21.0)
# Requirement already satisfied: google-cloud-monitoring~=2.0 in c:\users\amana\anaconda3\lib\site-packages (from opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0->google-adk) (2.28.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in c:\users\amana\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in c:\users\amana\anaconda3\lib\site-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in c:\users\amana\anaconda3\lib\site-packages (from opentelemetry-sdk<=1.37.0,>=1.37.0->google-adk) (0.58b0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\amana\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\amana\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0->google-adk) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\amana\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.4.2)
# Requirement already satisfied: six>=1.5 in c:\users\amana\appdata\roaming\python\python313\site-packages (from python-dateutil<3.0.0,>=2.9.0.post0->google-adk) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\amana\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.4->google-adk) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\amana\anaconda3\lib\site-packages (from requests<3.0.0,>=2.32.4->google-adk) (2.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\amana\anaconda3\lib\site-packages (from rsa<5,>=3.1.4->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.4.8)
# Requirement already satisfied: numpy>=1.21 in c:\users\amana\anaconda3\lib\site-packages (from shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.1.3)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\amana\anaconda3\lib\site-packages (from sqlalchemy<3.0.0,>=2.0->google-adk) (3.1.1)
# Requirement already satisfied: tzdata in c:\users\amana\anaconda3\lib\site-packages (from tzlocal<6.0,>=5.3->google-adk) (2025.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\amana\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\amana\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\amana\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\amana\anaconda3\lib\site-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (0.22.3)
# Requirement already satisfied: cffi>=1.12 in c:\users\amana\anaconda3\lib\site-packages (from cryptography->authlib<2.0.0,>=1.5.1->google-adk) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\amana\anaconda3\lib\site-packages (from cffi>=1.12->cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.21)
# Requirement already satisfied: alembic in c:\users\amana\anaconda3\lib\site-packages (from sqlalchemy-spanner>=1.14.0->google-adk) (1.16.5)
# Requirement already satisfied: Mako in c:\users\amana\anaconda3\lib\site-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk) (1.2.3)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\amana\anaconda3\lib\site-packages (from Mako->alembic->sqlalchemy-spanner>=1.14.0->google-adk) (3.0.2)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 get_ipython().system('pip install google-adk')
#       2 import os
# ----> 3 from kaggle_secrets import UserSecretsClient
#       5 try:
#       6     GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
#
# ModuleNotFoundError: No module named 'kaggle_secrets'

# %%
from google.adk.agents import Agent
from google.adk.runners import InMemoryRunner
from google.adk.tools import google_search
from google.genai import types

print("✅ ADK components imported successfully.")

# %%
root_agent = Agent(
    name="helpful_assistant",
    model="gemini-2.5-flash-lite",
    description="A simple agent that can answer general questions.",
    instruction="You are a helpful assistant. Use Google Search for current info or if unsure.",
    tools=[google_search],
)

print("✅ Root Agent defined.")

# %%
runner = InMemoryRunner(agent=root_agent)

print("✅ Runner created.")

# %%
response = await runner.run_debug("What is Agent Development Kit from Google? What languages is the SDK available in?")

# %%
response = await runner.run_debug("What's the weather in London?")

# %%
#ADK WEB INTERFACE INITIALIZATION

# %%
# !adk create sample-agent --model gemini-2.5-flash-lite --api_key $GOOGLE_API_KEY

# %%
url_prefix = get_adk_proxy_url()

# %%
# !adk web --url_prefix {url_prefix}
